# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
#for image processing(python image processing)
from queue import Queue
#optional package

# %%
image=Image.open('image.jpg')
grayscale_image=image.convert('L')
#in DBSCAN colors don't matter, so we can 
#simplify the process by turning the image into
#mode 'L' which means grayscale(black and white)

# %%
image_array=np.array(grayscale_image)
#creating a 2D numpy array where each element 
#stores the intensity(how black or how white)
#of each pixel
height,width=image_array.shape
#image_array.shape returns a tuple

# %%
data=[]
for x in range (width):
    for y in range (height):
        intensity = image_array[y,x]
        data.append([x,y,intensity])
#creating a list of pixel coordinates with
#intensity values
data=np.array(data)
#turning the data list into a np array

# %%
class DBSCAN:
    def __init__(self, eps, min_samples):
        # Initialize the DBSCAN model with the given parameters.
        # eps: Maximum distance between two samples for them to be considered as in the same neighborhood.
        # min_samples: Minimum number of points required to form a dense region (cluster).
        self.eps = eps
        self.min_samples = min_samples
        self.labels_ = None  # To store cluster labels for each data point

    def euclidean_distance(self, point1, point2):
        # Calculate the Euclidean distance(the one we have in coordinates!) between two points.
        # point1, point2: Points represented as numpy arrays
        return np.sqrt(np.sum((point1 - point2)**2))  

    def fit(self, data):
        # Fit the DBSCAN model to the data
        # data: 2D array where each row represents a point with coordinates and intensity

        # Create spatial grid for indexing
        grid_size = int(np.ceil(self.eps)) + 1  # Determine the size of grid cells based on eps
        grid = {}  # Dictionary(remember c++ maps???) to store points in each grid cell

        # Populate the grid with points
        for point in data:
            x, y = point[:2]  # Extract x and y coordinates
            grid_x, grid_y = int(x // grid_size), int(y // grid_size)  # Determine the grid cell coordinates!
            if (grid_x, grid_y) not in grid:
                grid[(grid_x, grid_y)] = []  # Initialize list for new grid cells
            grid[(grid_x, grid_y)].append(point)  # Add the point to the corresponding grid cell

        labels = -1 * np.ones(data.shape[0], dtype=int)  # Initialize labels: -1 indicates unclassified points:(
        cluster_id = 0  # Initialize cluster ID counter
        total_points = data.shape[0]  # Total number of points in the dataset(used in counter) :)

        def get_neighbors(point):
            # Retrieve neighbors of a given point within eps distance
            x, y = point[:2]  # Extract x and y coordinates
            grid_x, grid_y = int(x // grid_size), int(y // grid_size)  # Determine the grid cell coordinates
            neighbors = []  # List to store neighbor points

            # Check neighboring grid cells
            for dx in range(-1, 2):  # Iterate over neighboring grid cells in x direction
                for dy in range(-1, 2):  # Iterate over neighboring grid cells in y direction
                    check_grid = grid.get((grid_x + dx, grid_y + dy), [])  # Get points from the neighboring grid cell
                    for neighbor in check_grid:
                        if self.euclidean_distance(point, neighbor) <= self.eps:
                            neighbors.append(neighbor)  # Add neighbor if it is within eps distance
            return neighbors  # Return the list of neighbors

        def expand_cluster(point_idx, neighbors):
            # Expand the cluster from a given core point and its neighbors
            labels[point_idx] = cluster_id  # Assign cluster ID to the core point
            i = 0
            while i < len(neighbors):
                neighbor = neighbors[i]  # Get the current neighbor point
                # Find the index of the neighbor point in the original data
                neighbor_idx = np.where(np.all(data == neighbor, axis=1))[0][0]

                if labels[neighbor_idx] == -1:
                    labels[neighbor_idx] = cluster_id  # Assign cluster ID to noise points
                elif labels[neighbor_idx] == 0:
                    labels[neighbor_idx] = cluster_id  # Assign cluster ID to unvisited points
                    new_neighbors = get_neighbors(neighbor)  # Get neighbors of the new point
                    if len(new_neighbors) >= self.min_samples:
                        neighbors.extend(new_neighbors)  # Add new neighbors to the list
                i += 1

        # Main loop to iterate over all data points
        for i, point in enumerate(data):
            if i % 100 == 0:  # Print progress every 100 points
                print(f"Processing point {i}/{total_points}")

            if labels[i] == -1:
                neighbors = get_neighbors(point)  # Find neighbors for the current point
                if len(neighbors) >= self.min_samples:
                    cluster_id += 1  # Increment cluster ID for a new cluster
                    expand_cluster(i, neighbors)  # Expand the cluster from the current point

        self.labels_ = labels  # Store the final cluster labels
        return self  # Return the DBSCAN object for  chaining!!!

# %%
dbscan=DBSCAN(eps=50,min_samples=50)
#instantiating the class
dbscan.fit(data)
#fitting the model on preprocessed image
labels=dbscan.labels_
#assigning labels into the variable
unique_labels=np.unique(labels)
#checking unique cluster IDs found
print(f"Number of clusters found(with noise):{len(unique_labels)}")
# Out:
# Processing point 0/23828
# Processing point 100/23828
# Processing point 200/23828
# Processing point 300/23828
# Processing point 400/23828
# Processing point 500/23828
# Processing point 600/23828
# Processing point 700/23828
# Processing point 800/23828
# Processing point 900/23828
# Processing point 1000/23828
# Processing point 1100/23828
# Processing point 1200/23828
# Processing point 1300/23828
# Processing point 1400/23828
# Processing point 1500/23828
# Processing point 1600/23828
# Processing point 1700/23828
# Processing point 1800/23828
# Processing point 1900/23828
# Processing point 2000/23828
# Processing point 2100/23828
# Processing point 2200/23828
# Processing point 2300/23828
# Processing point 2400/23828
# Processing point 2500/23828
# Processing point 2600/23828
# Processing point 2700/23828
# Processing point 2800/23828
# Processing point 2900/23828
# Processing point 3000/23828
# Processing point 3100/23828
# Processing point 3200/23828
# Processing point 3300/23828
# Processing point 3400/23828
# Processing point 3500/23828
# Processing point 3600/23828
# Processing point 3700/23828
# Processing point 3800/23828
# Processing point 3900/23828
# Processing point 4000/23828
# Processing point 4100/23828
# Processing point 4200/23828
# Processing point 4300/23828
# Processing point 4400/23828
# Processing point 4500/23828
# Processing point 4600/23828
# Processing point 4700/23828
# Processing point 4800/23828
# Processing point 4900/23828
# Processing point 5000/23828
# Processing point 5100/23828
# Processing point 5200/23828
# Processing point 5300/23828
# Processing point 5400/23828
# Processing point 5500/23828
# Processing point 5600/23828
# Processing point 5700/23828
# Processing point 5800/23828
# Processing point 5900/23828
# Processing point 6000/23828
# Processing point 6100/23828
# Processing point 6200/23828
# Processing point 6300/23828
# Processing point 6400/23828
# Processing point 6500/23828
# Processing point 6600/23828
# Processing point 6700/23828
# Processing point 6800/23828
# Processing point 6900/23828
# Processing point 7000/23828
# Processing point 7100/23828
# Processing point 7200/23828
# Processing point 7300/23828
# Processing point 7400/23828
# Processing point 7500/23828
# Processing point 7600/23828
# Processing point 7700/23828
# Processing point 7800/23828
# Processing point 7900/23828
# Processing point 8000/23828
# Processing point 8100/23828
# Processing point 8200/23828
# Processing point 8300/23828
# Processing point 8400/23828
# Processing point 8500/23828
# Processing point 8600/23828
# Processing point 8700/23828
# Processing point 8800/23828
# Processing point 8900/23828
# Processing point 9000/23828
# Processing point 9100/23828
# Processing point 9200/23828
# Processing point 9300/23828
# Processing point 9400/23828
# Processing point 9500/23828
# Processing point 9600/23828
# Processing point 9700/23828
# Processing point 9800/23828
# Processing point 9900/23828
# Processing point 10000/23828
# Processing point 10100/23828
# Processing point 10200/23828
# Processing point 10300/23828
# Processing point 10400/23828
# Processing point 10500/23828
# Processing point 10600/23828
# Processing point 10700/23828
# Processing point 10800/23828
# Processing point 10900/23828
# Processing point 11000/23828
# Processing point 11100/23828
# Processing point 11200/23828
# Processing point 11300/23828
# Processing point 11400/23828
# Processing point 11500/23828
# Processing point 11600/23828
# Processing point 11700/23828
# Processing point 11800/23828
# Processing point 11900/23828
# Processing point 12000/23828
# Processing point 12100/23828
# Processing point 12200/23828
# Processing point 12300/23828
# Processing point 12400/23828
# Processing point 12500/23828
# Processing point 12600/23828
# Processing point 12700/23828
# Processing point 12800/23828
# Processing point 12900/23828
# Processing point 13000/23828
# Processing point 13100/23828
# Processing point 13200/23828
# Processing point 13300/23828
# Processing point 13400/23828
# Processing point 13500/23828
# Processing point 13600/23828
# Processing point 13700/23828
# Processing point 13800/23828
# Processing point 13900/23828
# Processing point 14000/23828
# Processing point 14100/23828
# Processing point 14200/23828
# Processing point 14300/23828
# Processing point 14400/23828
# Processing point 14500/23828
# Processing point 14600/23828
# Processing point 14700/23828
# Processing point 14800/23828
# Processing point 14900/23828
# Processing point 15000/23828
# Processing point 15100/23828
# Processing point 15200/23828
# Processing point 15300/23828
# Processing point 15400/23828
# Processing point 15500/23828
# Processing point 15600/23828
# Processing point 15700/23828
# Processing point 15800/23828
# Processing point 15900/23828
# Processing point 16000/23828
# Processing point 16100/23828
# Processing point 16200/23828
# Processing point 16300/23828
# Processing point 16400/23828
# Processing point 16500/23828
# Processing point 16600/23828
# Processing point 16700/23828
# Processing point 16800/23828
# Processing point 16900/23828
# Processing point 17000/23828
# Processing point 17100/23828
# Processing point 17200/23828
# Processing point 17300/23828
# Processing point 17400/23828
# Processing point 17500/23828
# Processing point 17600/23828
# Processing point 17700/23828
# Processing point 17800/23828
# Processing point 17900/23828
# Processing point 18000/23828
# Processing point 18100/23828
# Processing point 18200/23828
# Processing point 18300/23828
# Processing point 18400/23828
# Processing point 18500/23828
# Processing point 18600/23828
# Processing point 18700/23828
# Processing point 18800/23828
# Processing point 18900/23828
# Processing point 19000/23828
# Processing point 19100/23828
# Processing point 19200/23828
# Processing point 19300/23828
# Processing point 19400/23828
# Processing point 19500/23828
# Processing point 19600/23828
# Processing point 19700/23828
# Processing point 19800/23828
# Processing point 19900/23828
# Processing point 20000/23828
# Processing point 20100/23828
# Processing point 20200/23828
# Processing point 20300/23828
# Processing point 20400/23828
# Processing point 20500/23828
# Processing point 20600/23828
# Processing point 20700/23828
# Processing point 20800/23828
# Processing point 20900/23828
# Processing point 21000/23828
# Processing point 21100/23828
# Processing point 21200/23828
# Processing point 21300/23828
# Processing point 21400/23828
# Processing point 21500/23828
# Processing point 21600/23828
# Processing point 21700/23828
# Processing point 21800/23828
# Processing point 21900/23828
# Processing point 22000/23828
# Processing point 22100/23828
# Processing point 22200/23828
# Processing point 22300/23828
# Processing point 22400/23828
# Processing point 22500/23828
# Processing point 22600/23828
# Processing point 22700/23828
# Processing point 22800/23828
# Processing point 22900/23828
# Processing point 23000/23828
# Processing point 23100/23828
# Processing point 23200/23828
# Processing point 23300/23828
# Processing point 23400/23828
# Processing point 23500/23828
# Processing point 23600/23828
# Processing point 23700/23828
# Processing point 23800/23828
# Number of clusters found(with noise):41

# %%
clustered_image=labels.reshape((height,width))
#reshape the 1D array back into a 2D array of dimenstions

# %%
plt.imshow(clustered_image,cmap='tab20b')
#displaying an image from a 2D array and using a colormap
plt.colorbar()
#adds colorbar to the side of our plot, which shows 
#the mapping of colors to cluster labels and makes it easier to
#to identify which color corresponds to which cluster labels
plt.title('DBSCAN Clustered Image')
#adds title!
plt.show()
#render and display

#this will show us clusters and noise pixels(organizing the imageb)

# %%
plt.hist(data[:, 2], bins=50)
plt.title('Intensity Distribution')
plt.show()

# %%
plt.plot(image_array.mean(axis=1))  # Average intensity per row
plt.title('Average Intensity Per Row')
plt.xlabel('Row')
plt.ylabel('Intensity')
plt.show()
